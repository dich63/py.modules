% %%
surf(rand(15))

% %%
graphics_toolkit("gnuplot")

% %%
 available_graphics_toolkits()
% Out:
% ans =
% {
%   [1,1] = fltk
%   [1,2] = gnuplot
% }

% %%
loaded_graphics_toolkits()
% Out:
% ans =
% {
%   [1,1] = fltk
%   [1,2] = gnuplot
% }
